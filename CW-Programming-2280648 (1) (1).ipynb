# %% [markdown]
# # Chapter 1 (Descriptive Analytics)

# %% [markdown]
# ### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Reading the csv file

# %%
df_healthcare=pd.read_csv("healthcare-dataset-stroke-data.csv")

# %%
healthcare=df_healthcare.copy()

# %% [markdown]
# ### Top 5 rows of the Dataset

# %%
healthcare.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ### Size of the dataset

# %%
healthcare.shape
# Out:
# (5110, 12)

# %% [markdown]
# ### Default datatypes of the Attributes

# %%
healthcare.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %% [markdown]
# ### Converting the datatypes of the attributes for correct and logical analysis

# %%
# List of columns to convert to object data type 
columns_to_convert = ['hypertension','heart_disease','stroke']

# Converting the above specified columns to object data type in the 'healthcare' DataFrame
healthcare[columns_to_convert] = healthcare[columns_to_convert].astype('object')
healthcare.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension          object
# heart_disease         object
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                object
# dtype: object

# %% [markdown]
# ## 1.1 Basic Statistics of all Attributes

# %% [markdown]
# ### 1.1.1 Basic Statistics of 'gender' Attribute

# %%
healthcare['gender'].describe()
# Out:
# count       5110
# unique         3
# top       Female
# freq        2994
# Name: gender, dtype: object

# %%
healthcare['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.2 Basic Statistics of 'age' Attribute

# %%
healthcare['age'].describe()
# Out:
# count    5110.000000
# mean       43.226614
# std        22.612647
# min         0.080000
# 25%        25.000000
# 50%        45.000000
# 75%        61.000000
# max        82.000000
# Name: age, dtype: float64

# %% [markdown]
# ### 1.1.3 Basic Statistics of 'hypertension' Attribute

# %%
healthcare['hypertension'].describe()
# Out:
# count     5110
# unique       2
# top          0
# freq      4612
# Name: hypertension, dtype: int64

# %%
healthcare['hypertension'].value_counts()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.4 Basic Statistics of 'heart_disease' Attribute

# %%
healthcare['heart_disease'].describe()
# Out:
# count     5110
# unique       2
# top          0
# freq      4834
# Name: heart_disease, dtype: int64

# %%
healthcare['heart_disease'].value_counts()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.5 Basic Statistics of 'ever_married' Attribute

# %%
healthcare['ever_married'].describe()
# Out:
# count     5110
# unique       2
# top        Yes
# freq      3353
# Name: ever_married, dtype: object

# %%
healthcare['ever_married'].value_counts()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.6 Basic Statistics of 'work_type' Attribute

# %%
healthcare['work_type'].describe()
# Out:
# count        5110
# unique          5
# top       Private
# freq         2925
# Name: work_type, dtype: object

# %%
healthcare['work_type'].value_counts()
# Out:
# work_type
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.7 Basic Statistics of 'Residence_type' Attribute

# %%
healthcare['Residence_type'].describe()
# Out:
# count      5110
# unique        2
# top       Urban
# freq       2596
# Name: Residence_type, dtype: object

# %%
healthcare['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.8 Basic Statistics of 'avg_glucose_level' Attribute

# %%
healthcare['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %% [markdown]
# ### 1.1.9 Basic Statistics of 'bmi' Attribute

# %%
healthcare['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %% [markdown]
# ### 1.1.10 Basic Statistics of 'smoking_status' Attribute

# %%
healthcare['smoking_status'].describe()
# Out:
# count             5110
# unique               4
# top       never smoked
# freq              1892
# Name: smoking_status, dtype: object

# %%
healthcare['smoking_status'].value_counts()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64

# %% [markdown]
# ### 1.1.11 Basic Statistics of 'stroke' Attribute

# %%
healthcare['stroke'].describe()
# Out:
# count     5110
# unique       2
# top          0
# freq      4861
# Name: stroke, dtype: int64

# %%
healthcare['stroke'].value_counts()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# ### Alternate and fast way to retrieve the basic statistics for all categorical attrbutes

# %%
healthcare.describe(include='object')
# Out:
#         gender  hypertension  heart_disease ever_married work_type  \
# count     5110          5110           5110         5110      5110
# unique       3             2              2            2         5
# top     Female             0              0          Yes   Private
# freq      2994          4612           4834         3353      2925
#
#        Residence_type smoking_status  stroke
# count            5110           5110    5110
# unique              2              4       2
# top             Urban   never smoked       0
# freq             2596           1892    4861

# %% [markdown]
# ### Alternate and fast way to retrieve the basic statistics for all numerical attrbutes

# %%
healthcare.describe()
# Out:
#                  id          age  avg_glucose_level          bmi
# count   5110.000000  5110.000000        5110.000000  4909.000000
# mean   36517.829354    43.226614         106.147677    28.893237
# std    21161.721625    22.612647          45.283560     7.854067
# min       67.000000     0.080000          55.120000    10.300000
# 25%    17741.250000    25.000000          77.245000    23.500000
# 50%    36932.000000    45.000000          91.885000    28.100000
# 75%    54682.000000    61.000000         114.090000    33.100000
# max    72940.000000    82.000000         271.740000    97.600000

# %% [markdown]
# ## 1.2. Visualisations

# %% [markdown]
# ### 1.2.1 Boxplot to Analyse the Relationship between ‘Stroke’ and ‘Age’

# %%
plt.figure(figsize=(6, 6)) # setting the size of the figure

# Plotting the boxplot
sns.boxplot(x='stroke', y='age', data=healthcare)


plt.title('(Fig-1.2.1) Stroke vs Age', fontsize=12)
plt.xlabel('Stroke', fontsize=12)
plt.ylabel('Age', fontsize=12)


plt.xticks(rotation=0)


plt.tight_layout()


plt.show()

# %% [markdown]
# ### 1.2.2 Violinplot to Analyse the Relationship between 'Stroke' and 'BMI'

# %%
plt.figure(figsize=(6, 6)) # setting the size of the figure

# Plotting the violinplot
sns.violinplot(x='stroke', y='bmi', data=healthcare)


plt.title('(Fig-1.2.2) Stroke vs BMI', fontsize=12)
plt.xlabel('Stroke', fontsize=12)
plt.ylabel('BMI', fontsize=12)


plt.xticks(rotation=0)


plt.tight_layout()


plt.show()

# %% [markdown]
# ### 1.2.3 Scatter to Analyse the Relationship between 'bmi' and 'avg_glucose_level'

# %%
plt.figure(figsize=(6, 6)) # setting the size of the plot

# Plotting the scatterplot
sns.regplot(y='bmi',x='avg_glucose_level', data=healthcare)


plt.title('(Fig-1.2.3) BMI vs Glucose Level', fontsize=12)
plt.xlabel('avg_glucose_level', fontsize=12)
plt.ylabel('bmi', fontsize=12)
plt.xticks(rotation=0)



plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.2.4 Boxplot to Analyse the Relationship between 'Hypertension' and 'Age'

# %%
plt.figure(figsize=(6, 6)) # setting the size of the figure

# Plotting the boxplot
sns.boxplot(x='hypertension', y='age', data=healthcare)


plt.title('(Fig-1.2.4) Hypertension vs Age', fontsize=12)
plt.xlabel('Hypertension', fontsize=12)
plt.ylabel('Age', fontsize=12)


plt.xticks(rotation=0)


plt.tight_layout()


plt.show()

# %% [markdown]
# ### 1.2.5 Grouped Bar Chart to Analyse the Relationships between 'Heart Disease' and 'Stroke'

# %%
crosstab = pd.crosstab(df_healthcare['heart_disease'], df_healthcare['stroke'])

# Plotting the grouped bar chart
plot = crosstab.plot(kind='bar', figsize=(10, 6))

plt.title('(Fig-1.2.5) Heart Disease vs Stroke', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xlabel('Heart Disease', fontsize=12)
plt.xticks(rotation=0)
plt.legend(title='Stroke')

for container in plot.containers:
    plt.bar_label(container, fmt='%d', label_type='edge')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Chapter 2. Data Preparation

# %% [markdown]
# ### 2.1. Deleting the 'id' column

# %%
del df_healthcare['id']

# %%
df_healthcare.head()
# Out:
#    gender   age  hypertension  heart_disease ever_married      work_type  \
# 0    Male  67.0             0              1          Yes        Private
# 1  Female  61.0             0              0          Yes  Self-employed
# 2    Male  80.0             0              1          Yes        Private
# 3  Female  49.0             0              0          Yes        Private
# 4  Female  79.0             1              0          Yes  Self-employed
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# ### 2.2 Conversion of Necessary Columns to Numerical

# %%
df_healthcare.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()

# Applying LabelEncoder and printing the categories for each column
columns_to_encode = ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

for column in columns_to_encode:
    # Applying LabelEncoder
    df_healthcare[column] = LE.fit_transform(df_healthcare[column])
    
    # Print the mapping of category names to numerical values
    print(f"Mapping for {column}:")
    for i, category in enumerate(LE.classes_):
        print(f"{category} -> {i}")
    print("\n")
# Out:
# Mapping for gender:
# Female -> 0
# Male -> 1
# Other -> 2
#
#
# Mapping for ever_married:
# No -> 0
# Yes -> 1
#
#
# Mapping for work_type:
# Govt_job -> 0
# Never_worked -> 1
# Private -> 2
# Self-employed -> 3
# children -> 4
#
#
# Mapping for Residence_type:
# Rural -> 0
# Urban -> 1
#
#
# Mapping for smoking_status:
# Unknown -> 0
# formerly smoked -> 1
# never smoked -> 2
# smokes -> 3

# %%
# all attributes are now in numeric
df_healthcare.dtypes
# Out:
# gender                 int32
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int32
# work_type              int32
# Residence_type         int32
# avg_glucose_level    float64
# bmi                  float64
# smoking_status         int32
# stroke                 int64
# dtype: object

# %% [markdown]
# ### 2.3 Treating the Outliers

# %% [markdown]
# ### 2.3.1 Treating the Outliers for the 'bmi' Attribute

# %%
plt.figure(figsize=(6, 6)) # setting the size of the plot

# Plotting the boxplot
sns.boxplot(y='bmi', data=df_healthcare)


plt.title('Boxplot for BMI before treating the Outliers', fontsize=12)
plt.xlabel('bmi', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)



plt.tight_layout()
plt.show()

# %%
df_healthcare['bmi'].describe()
# Out:
# count    4909.000000
# mean       28.893237
# std         7.854067
# min        10.300000
# 25%        23.500000
# 50%        28.100000
# 75%        33.100000
# max        97.600000
# Name: bmi, dtype: float64

# %%
# Given values for Q1 and Q3 from the above description
Q1 = 23.5
Q3 = 33.1
IQR = Q3 - Q1

# Calculating the lower and upper limits
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# Clipping the 'bmi' column based on the calculated limits
df_healthcare['bmi'] = df_healthcare['bmi'].clip(lower=lower_limit, upper=upper_limit)

# %%
plt.figure(figsize=(6, 6)) # setting the size of the plot

# Plotting the boxplot
sns.boxplot(y='bmi', data=df_healthcare)


plt.title('Boxplot for BMI after treating the Outliers', fontsize=12)
plt.xlabel('bmi', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)



plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.3.2 Treating the outliers for the 'avg_glucose_level' attribute

# %%
plt.figure(figsize=(6, 6)) # setting the size of the plot

# Plotting the boxplot
sns.boxplot(y='avg_glucose_level', data=df_healthcare)


plt.title('Boxplot for avg_glucose_level before treating the Outliers', fontsize=12)
plt.xlabel('Avg Glucose Level', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)



plt.tight_layout()
plt.show()

# %%
df_healthcare['avg_glucose_level'].describe()
# Out:
# count    5110.000000
# mean      106.147677
# std        45.283560
# min        55.120000
# 25%        77.245000
# 50%        91.885000
# 75%       114.090000
# max       271.740000
# Name: avg_glucose_level, dtype: float64

# %%
# Given values for Q1 and Q3 based on the above description
Q1 = 77.245
Q3 = 114.09
IQR = Q3 - Q1

# Calculating the lower and upper limits
lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

# Clipping the 'bmi' column based on the calculated limits
df_healthcare['avg_glucose_level'] = df_healthcare['avg_glucose_level'].clip(lower=lower_limit, upper=upper_limit)

# %%
plt.figure(figsize=(6, 6)) # setting the size of the plot

# Plotting the boxplot
sns.boxplot(y='avg_glucose_level', data=df_healthcare)


plt.title('Boxplot for avg_glucose_level after treating the Outliers', fontsize=12)
plt.xlabel('Avg Glucose Level', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=90)



plt.tight_layout()
plt.show()

# %% [markdown]
# ### 2.4 Imputing missing values for Regression

# %%
df_regression=df_healthcare.copy()

# %%
df_regression.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df_regression = df_regression.dropna()

# %%
df_regression.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# ### 2.5 Segregating 'Features' and 'Target' for Regression

# %%
healthcare_reg=df_regression.drop(columns=['bmi']) # Features
y_reg=df_regression['bmi'].values # Target column

# %% [markdown]
# ### 2.6 Normalisation of the features for Regression

# %%
from sklearn import preprocessing
min_max_scaler=preprocessing.MinMaxScaler()
X_reg=min_max_scaler.fit_transform(healthcare_reg)

# %% [markdown]
# ### 2.7 Splitting the data into train and test for Regression

# %%
from sklearn.model_selection import train_test_split
X_train_reg, X_test_reg, y_train_reg, y_test_reg = train_test_split(X_reg,y_reg,test_size=0.25 ,random_state = 0)

# %% [markdown]
# ### 2.8 Imputing missing values for Classification

# %%
df_classification=df_healthcare.copy()

# %%
df_classification.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Computing the correlation matrix
correlation_matrix = df_classification.corr()

# Displaying the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("(Fig-2.8(A)) Correlation Heatmap")
plt.show()

# %%
df_classification['bmi'] = df_classification['bmi'].fillna(df_classification.groupby('age')['bmi'].transform('mean'))

# %%
df_classification.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# ### 2.9 Segregating 'Features' and 'Target' for Classification

# %%
# Splitting features and target
healthcare_clfn = df_classification.drop(columns=['stroke'])  # Features
y_clfn = df_classification['stroke'].values  # Target variable

# %% [markdown]
# ### 2.10 Normalisation of the Features for Classification

# %%
from sklearn import preprocessing
# Applying MinMaxScaler only to X_clfn (features)
min_max_scaler = preprocessing.MinMaxScaler()
X_clfn = min_max_scaler.fit_transform(healthcare_clfn)  # Scaled features

# %% [markdown]
# ### 2.11 Tackling Class Imbalance of the target column ('stroke') using SMOTE (Synthetic Minority Oversampling Technique)

# %%
df_healthcare['stroke'].value_counts().plot(kind='pie', autopct='%1.1f%%', title=' (Fig-2.11 A) Stroke Column Class Distribution')
plt.ylabel('')  
plt.show()

# %%
from imblearn.over_sampling import SMOTE
smote=SMOTE(random_state=10)
X1,Y1=smote.fit_resample(X_clfn,y_clfn)

# %%
# Converting Y1 to a Pandas Series
Y1_series = pd.Series(Y1)

# Plotting the pie chart for Y1 distribution
Y1_series.value_counts().plot(kind='pie', autopct='%1.1f%%', title=' (Fig-2.11 C) Stroke Column Class Distribution after oversampling using SMOTE')
plt.ylabel('')  
plt.show()

# %% [markdown]
# ### 2.12 Splitting the balanced dataset into train and test set for Classification

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X1,Y1,test_size=0.25 ,random_state = 0)

# %% [markdown]
# ### 2.13 Normalisation of the attributes for Clustering

# %%
df_clustering=df_classification.copy()

# %%
from sklearn import preprocessing
import pandas as pd


min_max_scaler = preprocessing.MinMaxScaler()

# Applying Min-Max scaling and converting back to a DataFrame
df_clust_norm = pd.DataFrame(min_max_scaler.fit_transform(df_clustering), columns=df_clustering.columns)

# %%
df_clust_norm1=df_clust_norm.copy()# it will be used for k medoids

# %%
df_clust_norm.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df_clust_norm1.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
# # Chapter 3 (Classification)

# %% [markdown]
# ### 3.1 Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import numpy as np

# parameters grid for GridSearchCV
parameters = {
'n_estimators': [100, 200, 300],  
'max_depth': [10, 20, 30],        
'min_samples_split': [2, 5, 10],  
'min_samples_leaf': [1, 2, 4],    
'criterion':['gini','entropy','log_loss'],    
'max_features': ['sqrt', 'log2']  
}

# Initializing the RandomForestClassifier
RF = RandomForestClassifier(random_state=0)

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=RF, param_grid=parameters, 
                           cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train, y_train)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_RF = grid_search.best_estimator_
y_pred = best_RF.predict(X_test)

# Performance metrics
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Getting predicted probabilities for the positive class
y_proba = best_RF.predict_proba(X_test)[:, 1]

# AUC calculation using predicted probabilities
print("AUC:", roc_auc_score(y_test, y_proba))
# Out:
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Best Parameters: {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
# Confusion Matrix:
#  [[1154   62]
#  [  48 1167]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      1216
#            1       0.95      0.96      0.95      1215
#
#     accuracy                           0.95      2431
#    macro avg       0.95      0.95      0.95      2431
# weighted avg       0.95      0.95      0.95      2431
#
# Accuracy: 0.9547511312217195
# AUC: 0.9919658327918561

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predicted probabilities for the positive class
y_proba = best_RF.predict_proba(X_test)[:, 1]

# Computing FPR, TPR, and AUC
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:}")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Fig-3.1A ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### 3.2 Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, roc_auc_score
import numpy as np

# Parameters grid for GridSearchCV
parameters = {
    'n_estimators': [50, 100, 150],  # Number of base estimators
    'max_samples': [0.5, 0.7, 1.0],  # Proportion of samples for training each base estimator
    'max_features': [0.5, 0.7, 1.0],  # Proportion of features for training each base estimator
    'bootstrap': [True, False],  # Whether samples are drawn with replacement
    'bootstrap_features': [True, False]  # Whether features are drawn with replacement
}

# Initializing the BaggingClassifier
BC = BaggingClassifier(random_state=0)

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=BC, param_grid=parameters, 
                           cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train, y_train)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_BC = grid_search.best_estimator_
y_pred = best_BC.predict(X_test)

# Performance metrics
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Getting predicted probabilities for the positive class
y_proba = best_BC.predict_proba(X_test)[:, 1]

# AUC calculation using predicted probabilities
print("AUC:", roc_auc_score(y_test, y_proba))
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# Best Parameters: {'bootstrap': False, 'bootstrap_features': True, 'max_features': 0.7, 'max_samples': 0.7, 'n_estimators': 100}
#
# Confusion Matrix:
#  [[1212    4]
#  [  72 1143]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97      1216
#            1       1.00      0.94      0.97      1215
#
#     accuracy                           0.97      2431
#    macro avg       0.97      0.97      0.97      2431
# weighted avg       0.97      0.97      0.97      2431
#
# Accuracy: 0.9687371452077335
# AUC: 0.9930714614468271

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predicted probabilities for the positive class
y_proba = best_BC.predict_proba(X_test)[:, 1]

# Computing FPR, TPR, and AUC
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:}")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Fig-3.2A ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### 3.3 KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# Parameters grid for GridSearchCV
parameters = {
    'n_neighbors': [3, 4, 5, 6, 7],       # Number of neighbors to use
    'weights':['uniform','distance'],
    'p': [1, 2]                    # Power parameter for Minkowski distance (1: Manhattan, 2: Euclidean)
}

# Initializing the KNeighborsClassifier
KNN = KNeighborsClassifier()

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=KNN, param_grid=parameters, 
                           cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train, y_train)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_KNN = grid_search.best_estimator_
y_pred = best_KNN.predict(X_test)

# Performance metrics
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Getting predicted probabilities for the positive class
y_proba = best_KNN.predict_proba(X_test)[:, 1]

# AUC calculation using predicted probabilities
print("AUC:", roc_auc_score(y_test, y_proba))
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best Parameters: {'n_neighbors': 4, 'p': 1, 'weights': 'distance'}
#
# Confusion Matrix:
#  [[1071  145]
#  [   6 1209]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.88      0.93      1216
#            1       0.89      1.00      0.94      1215
#
#     accuracy                           0.94      2431
#    macro avg       0.94      0.94      0.94      2431
# weighted avg       0.94      0.94      0.94      2431
#
# Accuracy: 0.9378856437679967
# AUC: 0.9697432721464154

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predicted probabilities for the positive class
y_proba = best_KNN.predict_proba(X_test)[:, 1]

# Computing FPR, TPR, and AUC
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:}")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Fig-3.3A ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### 3.4 AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# Parameters grid for GridSearchCV
parameters = {
    'n_estimators': [100, 150,200,250],  # Number of boosting rounds
    'learning_rate': [0.001,0.01, 0.1, 1.0,2.0],  # Learning rate
    'algorithm': ['SAMME', 'SAMME.R']  # Boosting algorithms
}

# Initializing the AdaBoostClassifier
ABC = AdaBoostClassifier(random_state=0)

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=ABC, param_grid=parameters, 
                           cv=5, scoring='accuracy', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train, y_train)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_ABC = grid_search.best_estimator_
y_pred = best_ABC.predict(X_test)

# Performance metrics
print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy:", accuracy_score(y_test, y_pred))

# Getting predicted probabilities for the positive class
y_proba = best_ABC.predict_proba(X_test)[:, 1]

# AUC calculation using predicted probabilities
print("AUC:", roc_auc_score(y_test, y_proba))
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# Best Parameters: {'algorithm': 'SAMME.R', 'learning_rate': 1.0, 'n_estimators': 250}
#
# Confusion Matrix:
#  [[1106  110]
#  [ 145 1070]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.88      0.91      0.90      1216
#            1       0.91      0.88      0.89      1215
#
#     accuracy                           0.90      2431
#    macro avg       0.90      0.90      0.90      2431
# weighted avg       0.90      0.90      0.90      2431
#
# Accuracy: 0.8951048951048951
# AUC: 0.9665417884990254

# %% [markdown]
# ### ROC Curve

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Predicted probabilities for the positive class
y_proba = best_ABC.predict_proba(X_test)[:, 1]

# Computing FPR, TPR, and AUC
fpr, tpr, _ = roc_curve(y_test, y_proba)
roc_auc = auc(fpr, tpr)

# Plotting the ROC curve
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:}")
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Fig-3.4A ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### Comparision of Classifiers used Above

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
classifiers = ['Bagging', 'Random Forest', 'KNN', 'AdaBoost']
f1_class_0 = [0.970, 0.950, 0.930, 0.900]
f1_class_1 = [0.970, 0.950, 0.940, 0.890]

# Plot
x = np.arange(len(classifiers))
width = 0.35

plt.figure(figsize=(10, 6))
bars1 = plt.bar(x, f1_class_0, width, label='Class 0')
bars2 = plt.bar(x + width, f1_class_1, width, label='Class 1')

# Adding values on top of bars
for bar in bars1 + bars2:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f"{bar.get_height():.3f}",
             ha='center', va='bottom', fontsize=10)

# Customizations 
plt.xticks(x + width / 2, classifiers)
plt.ylim(0.85, 1)
plt.title('Fig-3.5.1 F1 Scores by Classifier', fontsize=12)
plt.xlabel('Classifiers', fontsize=12)
plt.ylabel('F1 Score', fontsize=12)
plt.legend()

plt.show()

# %% [markdown]
# # Chapter 4 (Regression)

# %% [markdown]
# ### 4.1 Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Parameters grid for GridSearchCV
parameters = {
    'n_estimators': [100, 150, 200, 250],  # Number of boosting rounds
    'learning_rate': [0.001, 0.01, 0.1, 1.0, 2.0],  # Learning rate
    'max_depth': [3, 4, 5, 6],  # Maximum depth of trees
    'subsample': [0.6, 0.8, 1.0],  # Fraction of samples used for training
}

# Initializing the Gradient Boosting Regressor
GBR = GradientBoostingRegressor(random_state=0)

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=GBR, param_grid=parameters, 
                           cv=5, scoring='r2', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train_reg, y_train_reg)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_GBR = grid_search.best_estimator_
y_pred = best_GBR.predict(X_test_reg)

# Performance metrics
mae = mean_absolute_error(y_test_reg, y_pred)
mse = mean_squared_error(y_test_reg, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error
r2 = r2_score(y_test_reg, y_pred)

# Adjusted R²
adj_r2 = 1 - (1 - r2) * (len(y_pred) - 1) / (len(y_pred) - X_test_reg.shape[1] - 1)

# Evaluation metrics
print('\nMean Absolute Error:', mae)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print("R-squared Score:", r2)
print("Adjusted R² Score:", adj_r2)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# Best Parameters: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 250, 'subsample': 0.8}
#
# Mean Absolute Error: 4.640049614418671
# Mean Squared Error: 36.72390278396955
# Root Mean Squared Error: 6.060024982124212
# R-squared Score: 0.31517334730799607
# Adjusted R² Score: 0.3095461767846436

# %% [markdown]
# ### 4.2 Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Parameters grid for GridSearchCV
parameters = {
    'n_estimators': [100, 150, 200, 250],  # Number of trees in the forest
    'max_depth': [3, 4, 5, 6],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split a node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
    'bootstrap': [True, False]  # Whether bootstrap samples are used when building trees
}

# Initializing the Random Forest Regressor
RF = RandomForestRegressor(random_state=0)

# Initializing GridSearchCV
grid_search = GridSearchCV(estimator=RF, param_grid=parameters, 
                           cv=5, scoring='r2', verbose=2, n_jobs=-1)

# Performing the grid search on the training data
grid_search.fit(X_train_reg, y_train_reg)

# Best parameters from grid search
print("Best Parameters:", grid_search.best_params_)

# Predicting using the best model from GridSearchCV
best_RF = grid_search.best_estimator_
y_pred = best_RF.predict(X_test_reg)

# Performance metrics
mae = mean_absolute_error(y_test_reg, y_pred)
mse = mean_squared_error(y_test_reg, y_pred)
rmse = np.sqrt(mse)  # Root Mean Squared Error
r2 = r2_score(y_test_reg, y_pred)

# Adjusted R²
adj_r2 = 1 - (1 - r2) * (len(y_pred) - 1) / (len(y_pred) - X_test_reg.shape[1] - 1)

# Evaluation metrics
print('\nMean Absolute Error:', mae)
print('Mean Squared Error:', mse)
print('Root Mean Squared Error:', rmse)
print("R-squared Score:", r2)
print("Adjusted R² Score:", adj_r2)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# Best Parameters: {'bootstrap': True, 'max_depth': 6, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 200}
#
# Mean Absolute Error: 4.6195585118445655
# Mean Squared Error: 36.7353373558584
# Root Mean Squared Error: 6.060968351332846
# R-squared Score: 0.3149601156251417
# Adjusted R² Score: 0.3093311929926449

# %% [markdown]
# # Chapter 5 (Clustering)

# %% [markdown]
# ### 5.1 K-Means Clustering

# %%
df_clust_norm.dtypes
# Out:
# gender               float64
# age                  float64
# hypertension         float64
# heart_disease        float64
# ever_married         float64
# work_type            float64
# Residence_type       float64
# avg_glucose_level    float64
# bmi                  float64
# smoking_status       float64
# stroke               float64
# dtype: object

# %%
df_clust_norm.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0       0.50
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 3     0.0  0.597168           0.0            0.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# 0             1.0           1.000000  0.706989        0.333333     1.0
# 1             0.0           1.000000  0.529800        0.666667     1.0
# 2             0.0           0.444688  0.596774        0.666667     1.0
# 3             1.0           1.000000  0.647849        1.000000     1.0
# 4             0.0           1.000000  0.368280        0.666667     1.0

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# Fitting KMeans 
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(df_clust_norm)
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2, random_state=0)

# %%
# viewing the cluster centers
kmeans.cluster_centers_
# Out:
# array([[ 2.17663818e-01,  2.67021679e-01,  2.90598291e-02,
#          1.76638177e-02, -9.99200722e-16,  6.75213675e-01,
#          5.03703704e-01,  3.47304327e-01,  3.98618893e-01,
#          3.30484330e-01,  1.53846154e-02],
#        [ 2.01639344e-01,  6.62525615e-01,  1.33233979e-01,
#          7.30253353e-02,  9.99403875e-01,  4.72205663e-01,
#          5.10283159e-01,  4.29981046e-01,  5.47669077e-01,
#          5.26179831e-01,  6.61698957e-02]])

# %%
# Computing the silhouette score 
kmeans_silhouette = silhouette_score(df_clust_norm, kmeans.labels_).round(2)
print(kmeans_silhouette)
# Out:
# 0.27

# %% [markdown]
# ### Elbow Curve

# %%
# Elbow Curve
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

model = KMeans()
visualizer = KElbowVisualizer(model, k=(2,10), metric='calinski_harabasz')

visualizer.fit(df_clust_norm)      
visualizer.show()                            
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Silhoette Plot (for 2 clusters)

# %%
model = KMeans(n_clusters=2, random_state=0)

# Creating the SilhouetteVisualizer with the KMeans model
visualizer = SilhouetteVisualizer(model)

# Fitting the visualizer to the data
visualizer.fit(df_clust_norm)

# Displaying the silhouette plot
visualizer.show()
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# a new cluster column is created to store the labels of each data point
#appendding dataframe with cluster number
df_clust_norm['cluster'] = kmeans.labels_
df_clust_norm.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0       0.50
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 3     0.0  0.597168           0.0            0.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 0             1.0           1.000000  0.706989        0.333333     1.0
# 1             0.0           1.000000  0.529800        0.666667     1.0
# 2             0.0           0.444688  0.596774        0.666667     1.0
# 3             1.0           1.000000  0.647849        1.000000     1.0
# 4             0.0           1.000000  0.368280        0.666667     1.0
#
#    cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
#viewing proterties of each cluster
cluster1=df_clust_norm.query("cluster == 0")
cluster2=df_clust_norm.query("cluster == 1")

# %%
# top 5 rows of cluster1
cluster1.head()
# Out:
#     gender       age  hypertension  heart_disease  ever_married  work_type  \
# 7      0.0  0.841309           0.0            0.0           0.0        0.5
# 18     0.0  0.731445           0.0            0.0           0.0        0.5
# 19     0.5  0.694824           0.0            1.0           0.0        0.0
# 34     0.5  0.584961           0.0            0.0           0.0        0.0
# 35     0.0  1.000000           1.0            1.0           0.0        0.5
#
#     Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 7              1.0           0.343758  0.336022        0.666667     1.0
# 18             1.0           0.298501  0.739247        0.666667     1.0
# 19             1.0           1.000000  0.582322        0.000000     1.0
# 34             1.0           0.254557  0.521505        0.666667     1.0
# 35             0.0           0.253069  0.435484        0.333333     1.0
#
#     cluster
# 7         0
# 18        0
# 19        0
# 34        0
# 35        0

# %%
# Top 5 rows of cluster2
cluster2.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0       0.50
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 3     0.0  0.597168           0.0            0.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 0             1.0           1.000000  0.706989        0.333333     1.0
# 1             0.0           1.000000  0.529800        0.666667     1.0
# 2             0.0           0.444688  0.596774        0.666667     1.0
# 3             1.0           1.000000  0.647849        1.000000     1.0
# 4             0.0           1.000000  0.368280        0.666667     1.0
#
#    cluster
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1

# %%
# Statistical Summary of cluster1
cluster1.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  1755.000000  1755.000000   1755.000000    1755.000000        1755.0
# mean      0.217664     0.267022      0.029060       0.017664           0.0
# std       0.248545     0.224602      0.168022       0.131764           0.0
# min       0.000000     0.000000      0.000000       0.000000           0.0
# 25%       0.000000     0.108887      0.000000       0.000000           0.0
# 50%       0.000000     0.218750      0.000000       0.000000           0.0
# 75%       0.500000     0.340820      0.000000       0.000000           0.0
# max       1.000000     1.000000      1.000000       1.000000           0.0
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  1755.000000     1755.000000        1755.000000  1755.000000
# mean      0.675214        0.503704           0.347304     0.398619
# std       0.297387        0.500129           0.237150     0.194843
# ...

# %%
# Statistical Summary of cluster2
cluster2.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  3355.000000  3355.000000   3355.000000    3355.000000   3355.000000
# mean      0.201639     0.662526      0.133234       0.073025      0.999404
# std       0.245314     0.189588      0.339878       0.260217      0.024412
# min       0.000000     0.218750      0.000000       0.000000      0.000000
# 25%       0.000000     0.511719      0.000000       0.000000      1.000000
# 50%       0.000000     0.658203      0.000000       0.000000      1.000000
# 75%       0.500000     0.804688      0.000000       0.000000      1.000000
# max       0.500000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  3355.000000     3355.000000        3355.000000  3355.000000
# mean      0.472206        0.510283           0.429981     0.547669
# std       0.229704        0.499969           0.311466     0.173035
# ...

# %%
# Mean values in the clusters
cluster1_mean = kmeans.cluster_centers_[0]
cluster2_mean = kmeans.cluster_centers_[1]

print("Cluster 1 Mean:", cluster1_mean)
print("Cluster 2 Mean:", cluster2_mean)
# Out:
# Cluster 1 Mean: [ 2.17663818e-01  2.67021679e-01  2.90598291e-02  1.76638177e-02
#  -9.99200722e-16  6.75213675e-01  5.03703704e-01  3.47304327e-01
#   3.98618893e-01  3.30484330e-01  1.53846154e-02]
# Cluster 2 Mean: [0.20163934 0.66252561 0.13323398 0.07302534 0.99940387 0.47220566
#  0.51028316 0.42998105 0.54766908 0.52617983 0.0661699 ]

# %%
cluster1_mean_p1=cluster1_mean[:11]
cluster1_mean_p1
# Out:
# array([ 2.17663818e-01,  2.67021679e-01,  2.90598291e-02,  1.76638177e-02,
#        -9.99200722e-16,  6.75213675e-01,  5.03703704e-01,  3.47304327e-01,
#         3.98618893e-01,  3.30484330e-01,  1.53846154e-02])

# %%
cluster2_mean_p1 = cluster2_mean[:11]
cluster2_mean_p1
# Out:
# array([0.20163934, 0.66252561, 0.13323398, 0.07302534, 0.99940387,
#        0.47220566, 0.51028316, 0.42998105, 0.54766908, 0.52617983,
#        0.0661699 ])

# %% [markdown]
# ### Mean values per attribute for the two clusters

# %%
X = cluster1.keys()[:11]

  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_mean_p1, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_mean_p1, 0.3, label = 'Cluster2')
#plt.bar(X_axis + 0.4, cluster3_mean_p1, 0.3, label = 'Cluster3')
  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")

plt.ylabel("Mean values")
plt.title("Mean values per attribute for the two clusters")
plt.legend()
plt.show()

# %% [markdown]
# ### Denormalization of the values in cluster1 and cluster2 for correct interpretation

# %%
min_values = df_clustering.min()
max_values = df_clustering.max()


def denormalize(df_norm, min_values, max_values):
    return df_norm * (max_values - min_values) + min_values

# Denormalizing cluster1 and cluster2
cluster1_denorm = denormalize(cluster1, min_values, max_values)
cluster2_denorm = denormalize(cluster2, min_values, max_values)

# %%
cluster1_denorm.describe()
# Out:
#        Residence_type          age  avg_glucose_level          bmi  cluster  \
# count     1755.000000  1755.000000        1755.000000  1755.000000      0.0
# mean         0.503704    21.954416          94.795178    25.128623      NaN
# std          0.500129    18.399359          27.091477     7.248171      NaN
# min          0.000000     0.080000          55.120000    10.300000      NaN
# 25%          0.000000     9.000000          75.730000    19.500000      NaN
# 50%          1.000000    18.000000          89.030000    23.600000      NaN
# 75%          1.000000    28.000000         108.400000    29.100000      NaN
# max          1.000000    82.000000         169.357500    47.500000      NaN
#
#        ever_married       gender  heart_disease  hypertension  smoking_status  \
# count        1755.0  1755.000000    1755.000000   1755.000000     1755.000000
# mean            0.0     0.435328       0.017664      0.029060        0.991453
# ...

# %%
cluster2_denorm.describe()
# Out:
#        Residence_type          age  avg_glucose_level          bmi  cluster  \
# count     3355.000000  3355.000000        3355.000000  3355.000000      0.0
# mean         0.510283    54.354098         104.239960    30.673290      NaN
# std          0.499969    15.531081          35.581104     6.436911      NaN
# min          0.000000    18.000000          55.220000    11.300000      NaN
# 25%          0.000000    42.000000          78.025000    26.200000      NaN
# 50%          1.000000    54.000000          93.580000    29.800000      NaN
# 75%          1.000000    66.000000         120.240000    34.200000      NaN
# max          1.000000    82.000000         169.357500    47.500000      NaN
#
#        ever_married       gender  heart_disease  hypertension  smoking_status  \
# count   3355.000000  3355.000000    3355.000000   3355.000000     3355.000000
# mean       0.999404     0.403279       0.073025      0.133234        1.578539
# ...

# %% [markdown]
# ### Converting specific columns to 'Category' for correct and logical analysis of cluster1 and cluster2

# %%
exclude_columns = ['age', 'avg_glucose_level', 'bmi']
for col in cluster1_denorm.columns:
    if col not in exclude_columns:
        cluster1_denorm[col] = cluster1_denorm[col].astype('category')

# %%
exclude_columns = ['age', 'avg_glucose_level', 'bmi']

for col in cluster2_denorm.columns:
    if col not in exclude_columns:
        cluster2_denorm[col] = cluster2_denorm[col].astype('category')

# %%
# Statistical Summary of Numerical Features in cluster1
cluster1_denorm.describe()
# Out:
#                age  avg_glucose_level          bmi
# count  1755.000000        1755.000000  1755.000000
# mean     21.954416          94.795178    25.128623
# std      18.399359          27.091477     7.248171
# min       0.080000          55.120000    10.300000
# 25%       9.000000          75.730000    19.500000
# 50%      18.000000          89.030000    23.600000
# 75%      28.000000         108.400000    29.100000
# max      82.000000         169.357500    47.500000

# %%
# Statistical Summary of Categorical Features in cluster1
cluster1_denorm.describe(include='category')
# Out:
#         Residence_type cluster  ever_married  gender  heart_disease  \
# count           1755.0       0        1755.0  1755.0         1755.0
# unique             2.0       0           1.0     3.0            2.0
# top                1.0     NaN           0.0     0.0            0.0
# freq             884.0     NaN        1755.0   992.0         1724.0
#
#         hypertension  smoking_status  stroke  work_type
# count         1755.0          1755.0  1755.0     1755.0
# unique           2.0             4.0     2.0        5.0
# top              0.0             0.0     0.0        2.0
# freq          1704.0           901.0  1728.0      820.0

# %%
# Statistical Summary of Numerical Features in cluster2
cluster2_denorm.describe()
# Out:
#                age  avg_glucose_level          bmi
# count  3355.000000        3355.000000  3355.000000
# mean     54.354098         104.239960    30.673290
# std      15.531081          35.581104     6.436911
# min      18.000000          55.220000    11.300000
# 25%      42.000000          78.025000    26.200000
# 50%      54.000000          93.580000    29.800000
# 75%      66.000000         120.240000    34.200000
# max      82.000000         169.357500    47.500000

# %%
# Statistical Summary of Categorical Features in cluster2
cluster2_denorm.describe(include='category')
# Out:
#         Residence_type cluster  ever_married  gender  heart_disease  \
# count           3355.0       0        3355.0  3355.0         3355.0
# unique             2.0       0           2.0     2.0            2.0
# top                1.0     NaN           1.0     0.0            0.0
# freq            1712.0     NaN        3353.0  2002.0         3110.0
#
#         hypertension  smoking_status  stroke  work_type
# count         3355.0          3355.0  3355.0     3355.0
# unique           2.0             4.0     2.0        3.0
# top              0.0             2.0     0.0        2.0
# freq          2908.0          1364.0  3133.0     2105.0

# %% [markdown]
# ### 5.2 K-Medoids Clustering

# %%
from sklearn_extra.cluster import KMedoids
# Fitting KMedoids on the sampled data
kmedoids = KMedoids(n_clusters=2, random_state=0)
kmedoids.fit(df_clust_norm1)
# Out:
# KMedoids(n_clusters=2, random_state=0)

# %%
# Computing the silhouette score 
kmedoids_silhouette = silhouette_score(df_clust_norm1, kmedoids.labels_).round(2)
print(kmedoids_silhouette)
# Out:
# 0.23

# %%
# Elbow Curve
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

# initialising the model
model = KMedoids()
visualizer = KElbowVisualizer(model, k=(2,10), metric='calinski_harabasz')

visualizer.fit(df_clust_norm1)     
visualizer.show()                            
plt.show()

# %%
# Fitting KMedoids using 2 clusters
kmedoids = KMedoids(n_clusters=2, random_state=0)
kmedoids.fit(df_clust_norm1)
# Out:
# KMedoids(n_clusters=2, random_state=0)

# %%
kmedoids.labels_
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
# a new cluster column is created to store the labels of each data point
#appending dataframe with cluster number
df_clust_norm1['cluster'] = kmedoids.labels_
df_clust_norm1.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0       0.50
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 3     0.0  0.597168           0.0            0.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 0             1.0           1.000000  0.706989        0.333333     1.0
# 1             0.0           1.000000  0.529800        0.666667     1.0
# 2             0.0           0.444688  0.596774        0.666667     1.0
# 3             1.0           1.000000  0.647849        1.000000     1.0
# 4             0.0           1.000000  0.368280        0.666667     1.0
#
#    cluster
# 0        1
# 1        0
# 2        0
# 3        1
# 4        0

# %%
#viewing proterties of each cluster
cluster1=df_clust_norm1.query("cluster == 0")
cluster2=df_clust_norm1.query("cluster == 1")

# %%
# Top 5 rows of cluster1
cluster1.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
# 6     0.5  0.902344           1.0            1.0           1.0       0.50
# 8     0.0  0.719238           0.0            0.0           1.0       0.50
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 1             0.0           1.000000  0.529800        0.666667     1.0
# 2             0.0           0.444688  0.596774        0.666667     1.0
# 4             0.0           1.000000  0.368280        0.666667     1.0
# 6             0.0           0.131043  0.459677        0.666667     1.0
# 8             0.0           0.184090  0.558172        0.000000     1.0
#
#    cluster
# 1        0
# 2        0
# 4        0
# 6        0
# 8        0

# %%
# Top 5 rows of cluster2
cluster2.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0        0.5
# 3     0.0  0.597168           0.0            0.0           1.0        0.5
# 5     0.5  0.987793           0.0            0.0           1.0        0.5
# 7     0.0  0.841309           0.0            0.0           0.0        0.5
# 9     0.0  0.951172           0.0            0.0           1.0        0.5
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke  \
# 0             1.0           1.000000  0.706989        0.333333     1.0
# 3             1.0           1.000000  0.647849        1.000000     1.0
# 5             1.0           1.000000  0.502688        0.333333     1.0
# 7             1.0           0.343758  0.336022        0.666667     1.0
# 9             1.0           0.030200  0.373656        0.000000     1.0
#
#    cluster
# 0        1
# 3        1
# 5        1
# 7        1
# 9        1

# %%
# Statistical Summary of cluster1
cluster1.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  2514.000000  2514.000000   2514.000000    2514.000000   2514.000000
# mean      0.208831     0.522715      0.099841       0.053302      0.653142
# std       0.247039     0.274195      0.299847       0.224679      0.476065
# min       0.000000     0.000000      0.000000       0.000000      0.000000
# 25%       0.000000     0.304199      0.000000       0.000000      0.000000
# 50%       0.000000     0.536133      0.000000       0.000000      1.000000
# 75%       0.500000     0.743652      0.000000       0.000000      1.000000
# max       1.000000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  2514.000000          2514.0        2514.000000  2514.000000
# mean      0.543954             0.0           0.403377     0.495789
# std       0.269960             0.0           0.289293     0.192293
# ...

# %%
# Statistical summary of cluster2
cluster2.describe()
# Out:
#             gender          age  hypertension  heart_disease  ever_married  \
# count  2596.000000  2596.000000   2596.000000    2596.000000   2596.000000
# mean      0.205508     0.530544      0.095146       0.054700      0.659091
# std       0.246057     0.277800      0.293474       0.227437      0.474106
# min       0.000000     0.000000      0.000000       0.000000      0.000000
# 25%       0.000000     0.316406      0.000000       0.000000      0.000000
# 50%       0.000000     0.548340      0.000000       0.000000      1.000000
# 75%       0.500000     0.743652      0.000000       0.000000      1.000000
# max       0.500000     1.000000      1.000000       1.000000      1.000000
#
#          work_type  Residence_type  avg_glucose_level          bmi  \
# count  2596.000000          2596.0        2596.000000  2596.000000
# mean      0.539965             1.0           0.399852     0.497146
# std       0.275119             0.0           0.292203     0.195996
# ...

# %%
# Getting the indices of the medoids
cluster1_index = kmedoids.medoid_indices_[0]
cluster2_index = kmedoids.medoid_indices_[1]

# Getting the actual medoid data points (rows) from the sampled_data DataFrame
cluster1_medoid = df_clust_norm1.iloc[cluster1_index].values  
cluster2_medoid = df_clust_norm1.iloc[cluster2_index].values  


print("Cluster 1 Medoid:", cluster1_medoid)
print("Cluster 2 Medoid:", cluster2_medoid)
# Out:
# Cluster 1 Medoid: [0.         0.52392578 0.         0.         1.         0.5
#  0.         0.37141919 0.48387097 0.33333333 0.         0.        ]
# Cluster 2 Medoid: [0.         0.49951172 0.         0.         1.         0.5
#  1.         0.32406171 0.5188172  0.33333333 0.         1.        ]

# %%
cluster1_medoid=cluster1_medoid[:11]
cluster1_medoid
# Out:
# array([0.        , 0.52392578, 0.        , 0.        , 1.        ,
#        0.5       , 0.        , 0.37141919, 0.48387097, 0.33333333,
#        0.        ])

# %%
cluster2_medoid=cluster2_medoid[:11]
cluster2_medoid
# Out:
# array([0.        , 0.49951172, 0.        , 0.        , 1.        ,
#        0.5       , 1.        , 0.32406171, 0.5188172 , 0.33333333,
#        0.        ])

# %%
# viewing the first 11 columns
X = cluster1.keys()[:11]

  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, cluster1_medoid, 0.3, label = 'Cluster1')
plt.bar(X_axis + 0.1, cluster2_medoid, 0.3, label = 'Cluster2')

  
plt.xticks(X_axis, X, rotation='vertical')
plt.xlabel("Groups")

plt.ylabel("Medoid values")
plt.title("Medoid values per attribute for the two clusters")
plt.legend()
plt.show()

# %% [markdown]
# ### Denormalization of the values in cluster1 and cluster2 for correct interpretation

# %%
min_values = df_clustering.min()
max_values = df_clustering.max()


def denormalize(df_norm, min_values, max_values):
    return df_norm * (max_values - min_values) + min_values

# Denormalizing cluster1 and cluster2
cluster1_denorm = denormalize(cluster1, min_values, max_values)
cluster2_denorm = denormalize(cluster2, min_values, max_values)

# %% [markdown]
# ### Converting specific columns to 'Category' for correct and logical analysis of cluster1 and cluster2

# %%
exclude_columns = ['age', 'avg_glucose_level', 'bmi']
for col in cluster1_denorm.columns:
    if col not in exclude_columns:
        cluster1_denorm[col] = cluster1_denorm[col].astype('category')

# %%
exclude_columns = ['age', 'avg_glucose_level', 'bmi']

for col in cluster2_denorm.columns:
    if col not in exclude_columns:
        cluster2_denorm[col] = cluster2_denorm[col].astype('category')

# %%
# Statistical Summary of Numerical Features in cluster1
cluster1_denorm.describe()
# Out:
#                age  avg_glucose_level          bmi
# count  2514.000000        2514.000000  2514.000000
# mean     42.900811         101.200759    28.743369
# std      22.462089          33.048070     7.153297
# min       0.080000          55.120000    10.300000
# 25%      25.000000          77.420000    23.800000
# 50%      44.000000          92.955000    28.300000
# 75%      61.000000         114.515000    32.567059
# max      82.000000         169.357500    47.500000

# %%
# Statistical Summary of Numerical Features in cluster2

cluster2_denorm.describe()
# Out:
#                age  avg_glucose_level          bmi
# count  2596.000000        2596.000000  2596.000000
# mean     43.542126         100.798111    28.793833
# std      22.757380          33.380519     7.291051
# min       0.080000          55.220000    11.300000
# 25%      26.000000          77.042500    23.600000
# 50%      45.000000          90.770000    28.200000
# 75%      61.000000         113.767500    33.100000
# max      82.000000         169.357500    47.500000

# %%
# Statistical Summary of Categorical Features in cluster1

cluster1_denorm.describe(include='category')
# Out:
#         Residence_type cluster  ever_married  gender  heart_disease  \
# count           2514.0       0        2514.0  2514.0         2514.0
# unique             1.0       0           2.0     3.0            2.0
# top                0.0     NaN           1.0     0.0            0.0
# freq            2514.0     NaN        1642.0  1465.0         2380.0
#
#         hypertension  smoking_status  stroke  work_type
# count         2514.0          2514.0  2514.0     2514.0
# unique           2.0             4.0     2.0        5.0
# top              0.0             2.0     0.0        2.0
# freq          2263.0           961.0  2400.0     1462.0

# %%
# Statistical Summary of Categorical Features in cluster2

cluster2_denorm.describe(include='category')
# Out:
#         Residence_type cluster  ever_married  gender  heart_disease  \
# count           2596.0       0        2596.0  2596.0         2596.0
# unique             1.0       0           2.0     2.0            2.0
# top                1.0     NaN           1.0     0.0            0.0
# freq            2596.0     NaN        1711.0  1529.0         2454.0
#
#         hypertension  smoking_status  stroke  work_type
# count         2596.0          2596.0  2596.0     2596.0
# unique           2.0             4.0     2.0        5.0
# top              0.0             2.0     0.0        2.0
# freq          2349.0           931.0  2461.0     1463.0
